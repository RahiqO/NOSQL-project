# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Microsoft Windows [Version 10.0.19045.2965]
# (c) Microsoft Corporation. All rights reserved.

# C:\Users\16475>cd C:\Users\16475\Documents\GitLab resources\nosql-challenge\Resources

# C:\Users\16475\Documents\GitLab resources\nosql-challenge\Resources>dir
#  Volume in drive C has no label.
#  Volume Serial Number is 2025-92CF

#  Directory of C:\Users\16475\Documents\GitLab resources\nosql-challenge\Resources

# 2023-05-17  07:53 PM    <DIR>          .
# 2023-05-17  07:53 PM    <DIR>          ..
# 2023-05-17  07:53 PM        41,253,208 establishments.json
#                1 File(s)     41,253,208 bytes
#                2 Dir(s)  57,196,756,992 bytes free

# C:\Users\16475\Documents\GitLab resources\nosql-challenge\Resources>mongoimport mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json
# 2023-05-17T20:11:25.309-0400    error parsing command line options: error parsing positional arguments: provide only one file name and only one MongoDB connection string. Connection strings must begin with mongodb:// or mongodb+srv:// schemes
# 2023-05-17T20:11:25.310-0400    try 'mongoimport --help' for more information

# C:\Users\16475\Documents\GitLab resources\nosql-challenge\Resources>mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json
# 2023-05-17T20:11:45.948-0400    connected to: mongodb://localhost/
# 2023-05-17T20:11:45.954-0400    dropping: uk_food.establishments
# 2023-05-17T20:11:48.952-0400    [####################....] uk_food.establishments       33.6MB/39.3MB (85.5%)
# 2023-05-17T20:11:49.444-0400    [########################] uk_food.establishments       39.3MB/39.3MB (100.0%)
# 2023-05-17T20:11:49.444-0400    39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
# Use count_documents to display the number of documents in the result
# # Display the first document in the results using pprint
query = {'scores.Hygiene': 20}
print("Number of documents in result: ", establishments.count_documents(query))
print("First result:")
results = establishments.find(query)
pprint(results[0])
# Out:
# Number of documents in result:  41
# First result:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64656d422d3d0ad5d14618dc'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64656d422d3d0ad5d14618dc   110681                  0
# 1  64656d422d3d0ad5d1461c5a   612039                  0
# 2  64656d422d3d0ad5d1461f66   730933                  0
# 3  64656d422d3d0ad5d1462152   172735                  0
# 4  64656d422d3d0ad5d1462161   172953                  0
# 5  64656d432d3d0ad5d1462aff   512854                  0
# 6  64656d432d3d0ad5d1462d21  1537089                  0
# 7  64656d432d3d0ad5d146424d   155648                  0
# 8  64656d432d3d0ad5d1464690  1012883                  0
# 9  64656d432d3d0ad5d1464ea1   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
query = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte': 4}}

# Use count_documents to display the number of documents in the result
# count = establishments.count_documents(query)
print("Number of documents in result:", establishments.count_documents(query))

# Display the first result using pprint
result_london = establishments.find(query)
pprint(result_london[0])
# Out:
# Number of documents in result: 37
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64656d432d3d0ad5d14632f4'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
My_frame = establishments.find(query)

# Convert the result to a dictionary
# result_dict = dict(My_frame)

# Create a DataFrame
df = pd.DataFrame(My_frame)

# Print the DataFrame
print("documents in data frame:", len(df))
df
# Out:
# documents in data frame: 37
#                          _id   FHRSID  ChangesByServerID  \
# 0   64656d432d3d0ad5d14632f4   621707                  0
# 1   64656d432d3d0ad5d1463619  1130836                  0
# 2   64656d432d3d0ad5d1464166   293783                  0
# 3   64656d432d3d0ad5d1464773  1523645                  0
# 4   64656d432d3d0ad5d1464f69  1315095                  0
# 5   64656d432d3d0ad5d1464f6a   294474                  0
# 6   64656d442d3d0ad5d1465670   294900                  0
# 7   64656d442d3d0ad5d146777d   293756                  0
# 8   64656d442d3d0ad5d146777e  1252616                  0
# 9   64656d442d3d0ad5d1467b45   878523                  0
# 10  64656d442d3d0ad5d1467b47   902473                  0
# 11  64656d442d3d0ad5d1467b5d   293772                  0
# 12  64656d442d3d0ad5d1467b5e   294606                  0
# 13  64656d442d3d0ad5d1467b61   295107                  0
# 14  64656d442d3d0ad5d1467b69   295105                  0
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200 
longitude = 0.08384000 

query = {"RatingValue": 5,"geocode.latitude":{"$gte":latitude - degree_search, "$lte":latitude + degree_search}, 
         "geocode.longitude":{"$gte":longitude - degree_search, "$lte":longitude + degree_search }}
sort =  {'$sort': { 'scores.Hygiene': -1}}

# Print the results
limit = 5 

results = establishments.find(query).sort([("scores.Hygiene", 1)]).limit(5)
pprint(list(results))
# Out:
# [{'AddressLine1': '109 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Euro express',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.996158638568,
#   'FHRSID': 1538211,
#   'LocalAuthorityBusinessID': '15382',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '1901-01-01T00:00:00',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64656d442d3d0ad5d1467197'),
#   'geocode': {'latitude': 51.4877206, 'longitude': 0.0916219},
# ...

# %%
# Convert result to Pandas DataFrame
lat_long_df = pd.DataFrame(establishments.find(query).sort([("scores.Hygiene", 1)]).limit(5))
lat_long_df.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64656d442d3d0ad5d1467197  1538211                  0
# 1  64656d442d3d0ad5d146712c  1489059                  0
# 2  64656d442d3d0ad5d14672d4  1538214                  0
# 3  64656d442d3d0ad5d1467208  1516619                  0
# 4  64656d442d3d0ad5d1467151  1489058                  0
#
#   LocalAuthorityBusinessID          BusinessName             BusinessType  \
# 0                    15382          Euro express        Retailers - other
# 1                    15077  Kingsmeat Smokehouse  Other catering premises
# 2                    15385   Plumstead suya spot   Takeaway/sandwich shop
# 3                    15218     Crab and Crayfish           Mobile caterer
# 4                    15076     Supreme Education          Caring Premises
#
#    BusinessTypeID                          AddressLine1 AddressLine2  \
# 0            4613             109 Plumstead High Street
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0

pipeline = [ {'$match': {'scores.Hygiene': 0 }},
           {'$group': {'_id': "$LocalAuthorityName", 'count' : {'$sum':1}}},
           {'$sort': { 'match_query': -1}}]


results = list(establishments.aggregate(pipeline))
print("Number of establishments in result: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of establishments in result:  55
# [{'_id': 'Newham', 'count': 711},
#  {'_id': 'Reading', 'count': 1},
#  {'_id': 'Wealden', 'count': 93},
#  {'_id': 'Ashford', 'count': 427},
#  {'_id': 'City of London Corporation', 'count': 28},
#  {'_id': 'Uttlesford', 'count': 251},
#  {'_id': 'Thurrock', 'count': 313},
#  {'_id': 'Tandridge', 'count': 42},
#  {'_id': 'Canterbury City', 'count': 298},
#  {'_id': 'Dartford', 'count': 383}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))

# Display the first 10 rows of the DataFrame
result_df
# Out:
# Rows in DataFrame:  55
#                            _id  count
# 0                       Newham    711
# 1                      Reading      1
# 2                      Wealden     93
# 3                      Ashford    427
# 4   City of London Corporation     28
# 5                   Uttlesford    251
# 6                     Thurrock    313
# 7                    Tandridge     42
# 8              Canterbury City    298
# 9                     Dartford    383
# 10               Tower Hamlets      9
# 11                   Gravesham    339
# 12                     Babergh     97
# 13                  Sunderland      1
# 14              Waltham Forest    110
# 15                      Dorset      1
# 16                     Bromley    460
# 17         North Hertfordshire      6
# 18                      Thanet   1130
# 19             Southend-On-Sea    586
# 20                      Bexley    607
# 21             Tunbridge Wells    491
# 22               North Norfolk      1
# ...
